# %% [markdown]
# # Figure 1e
#
# This notebook recreates the visualization shown in figure 1e in the reference article.
#
# > Same t-SNE plot as (C) [t-SNE plot of the integrated scRNA-seq profiles of epithelial cells form 11 reduction mammoplasties.] but colored by cell clusters (with Suerat cluster resolution set to 0.015)
#
# <div style="text-align: center;">
#     <img src="images/figure-1e-reference.png" alt="Figure 1e from Reference Article" width="50%">
#     <p style="font-size:90%; color:gray; text-align: center;"><em>Figure 1e from Reference Article</em></p>
# </div>

# %% [markdown]
# ## 0. Initializations

# %%
# -- imports --
from signals_in_the_noise.preprocessing.gse161529 import GSE161529
from signals_in_the_noise.utilities.visualization import get_figure_axes

# %%
# -- dataset --
gse = GSE161529()
all_real, all_noise = gse.get_combined_epithilial_dataset(real_pca_kwargs={}, noise_pca_kwargs={}, hvg_post_stromal=True)
# Out:
# 2025-11-04 23:08:29,931 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909253_N-PM0092-Total.h5ad as AnnData object.
# 2025-11-04 23:08:30,079 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909254_N-PM0019-Total.h5ad as AnnData object.
# 2025-11-04 23:08:30,211 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909255_N-N280-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:30,288 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909256_N-PM0095-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:30,526 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909257_N-PM0095-Total.h5ad as AnnData object.
# 2025-11-04 23:08:30,650 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909258_N-NF-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:30,720 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909259_N-NE-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:30,806 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909260_N-N1105-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:30,946 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909261_N-PM0230-Total.h5ad as AnnData object.
# 2025-11-04 23:08:31,114 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909262_N-MH0064-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:31,335 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909263_N-MH0064-Total.h5ad as AnnData object.
# 2025-11-04 23:08:31,421 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909264_N-N1B-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:31,526 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909265_N-PM0233-Total.h5ad as AnnData object.
# 2025-11-04 23:08:31,724 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909266_N-MH0169-Total.h5ad as AnnData object.
# 2025-11-04 23:08:31,858 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909267_N-MH0023-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:31,959 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909268_N-MH0023-Total.h5ad as AnnData object.
# 2025-11-04 23:08:32,181 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909269_N-PM0342-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:32,321 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909270_N-PM0342-Total.h5ad as AnnData object.
# 2025-11-04 23:08:32,476 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909271_N-MH288-Total.h5ad as AnnData object.
# 2025-11-04 23:08:32,550 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909272_N-MH0021-Total.h5ad as AnnData object.
# 2025-11-04 23:08:32,607 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909273_N-MH275-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:32,721 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909274_N-MH275-Total.h5ad as AnnData object.
# 2025-11-04 23:08:32,805 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909275_N-PM0372-Epi.h5ad as AnnData object.
# 2025-11-04 23:08:33,116 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909276_N-PM0372-Total.h5ad as AnnData object.
# 2025-11-04 23:08:33,230 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909277_B1-KCF0894.h5ad as AnnData object.
# 2025-11-04 23:08:33,346 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909278_B1-MH0033.h5ad as AnnData object.
# 2025-11-04 23:08:33,448 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909279_B1-MH0023.h5ad as AnnData object.
# 2025-11-04 23:08:33,534 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909280_B1-MH0090.h5ad as AnnData object.
# 2025-11-04 23:08:33,619 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909281_TN-MH0126.h5ad as AnnData object.
# 2025-11-04 23:08:33,709 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909282_TN-MH0135.h5ad as AnnData object.
# 2025-11-04 23:08:34,030 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909283_TN-SH0106.h5ad as AnnData object.
# 2025-11-04 23:08:34,090 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909284_TN-MH0114-T2.h5ad as AnnData object.
# 2025-11-04 23:08:34,179 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909285_TN-B1-MH4031.h5ad as AnnData object.
# 2025-11-04 23:08:34,370 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4
[INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909321_mER-MH0068-LN.h5ad as AnnData object.
# 2025-11-04 23:08:39,076 [INFO] signals_in_the_noise.preprocessing.gse161529: Loading combined datasets...

# %% [markdown]
# ## 1. "Real" cells

# %%
gse.visualize_tsne(all_real, color=['predicted_type', 'leiden'])

# %%
gse.visualize_tsne(all_real, color=['log1p_total_counts', 'log1p_n_genes_by_counts'], plot_kwargs={'cmap': 'gist_heat'})

# %%
gse.visualize_tsne(all_real, color=['pct_counts_mt'], plot_kwargs={'cmap': 'gist_heat'})

# %% [markdown]
# ## 2. "Noise" cells

# %%
gse.visualize_tsne(all_noise, color=['predicted_type', 'leiden'])

# %%
gse.visualize_tsne(all_noise, color=['log1p_total_counts', 'log1p_n_genes_by_counts'])

# %%
gse.visualize_tsne(all_noise, color=['pct_counts_mt'])

# %% [markdown]
# #### 2.a. Gather numbers for paper

# %%
mito_high = all_noise.obs['pct_counts_mt'].describe()['75%']
mito_mod = all_noise.obs['pct_counts_mt'].describe()['50%']
mito_lo = all_noise.obs['pct_counts_mt'].describe()['25%']
rna_high = all_noise.obs['log1p_total_counts'].describe()['75%']
rna_mod = all_noise.obs['log1p_total_counts'].describe()['50%']
rna_lo = all_noise.obs['log1p_total_counts'].describe()['25%']
gene_high = all_noise.obs['log1p_n_genes_by_counts'].describe()['75%']
gene_mod = all_noise.obs['log1p_n_genes_by_counts'].describe()['50%']
gene_lo = all_noise.obs['log1p_n_genes_by_counts'].describe()['25%']

mask_mito_high = all_noise.obs['pct_counts_mt'] >= mito_high
mask_genes_high = all_noise.obs['log1p_n_genes_by_counts'] >= gene_high

mask_mito_moderate = (all_noise.obs['pct_counts_mt'] > mito_lo) & (all_noise.obs['pct_counts_mt'] < mito_high)
mask_rna_moderate = (all_noise.obs['log1p_total_counts'] > rna_lo) & (all_noise.obs['log1p_total_counts'] < rna_high)
mask_genes_moderate = (all_noise.obs['log1p_n_genes_by_counts'] > gene_lo) & (all_noise.obs['log1p_n_genes_by_counts'] < gene_high)

mask_mito_low = all_noise.obs['pct_counts_mt'] <= mito_lo
mask_rna_low = all_noise.obs['log1p_total_counts'] <= rna_lo
mask_genes_low = all_noise.obs['log1p_n_genes_by_counts'] <= gene_lo

# %%
mask_damaged = mask_mito_high & mask_rna_low & mask_genes_low
mask_dormant = mask_mito_low & mask_rna_low & mask_genes_moderate
mask_multifunction = mask_mito_moderate & mask_rna_moderate & mask_genes_high

all_noise.obs['damaged'] = mask_damaged.astype(bool)
all_noise.obs['dormant'] = mask_dormant.astype(bool)
all_noise.obs['multifunction'] = mask_multifunction.astype(bool)

# %%
(all_noise.shape[0],
 all_noise.obs['damaged'].sum(),
 all_noise.obs['damaged'].sum()/all_noise.shape[0],
 all_noise.obs['dormant'].sum(),
 all_noise.obs['dormant'].sum()/all_noise.shape[0],
 all_noise.obs['multifunction'].sum(),
 all_noise.obs['multifunction'].sum()/all_noise.shape[0],
 )
# Out:
# (5014,
#  np.int64(214),
#  np.float64(0.04268049461507778),
#  np.int64(539),
#  np.float64(0.10749900279218189),
#  np.int64(115),
#  np.float64(0.022935779816513763))

# %%
all_noise.obs[all_noise.obs['damaged'] == 1][['is_low_num_genes', 'is_high_num_genes', 'is_high_mito', 'is_high_total_count']].describe().loc['max', :]
# Out:
# is_low_num_genes       1.0
# is_high_num_genes      0.0
# is_high_mito           1.0
# is_high_total_count    0.0
# Name: max, dtype: float64

# %%
all_noise.obs[all_noise.obs['dormant'] == 1][['is_low_num_genes', 'is_high_num_genes', 'is_high_mito', 'is_high_total_count']].describe().loc['max', :]
# Out:
# is_low_num_genes       1.0
# is_high_num_genes      0.0
# is_high_mito           0.0
# is_high_total_count    0.0
# Name: max, dtype: float64

# %%
all_noise.obs[all_noise.obs['multifunction'] == 1][['is_low_num_genes', 'is_high_num_genes', 'is_high_mito', 'is_high_total_count']].describe().loc['max', :]
# Out:
# is_low_num_genes       0.0
# is_high_num_genes      0.0
# is_high_mito           1.0
# is_high_total_count    0.0
# Name: max, dtype: float64

# %% [markdown]
# ### 3. UMAPs

# %%
import scanpy as sc
sc.tl.umap(all_noise)
sc.tl.umap(all_real)

# %%
sc.pl.umap(all_real, color=['predicted_type', 'leiden'])

# %%
sc.pl.umap(all_real, color=['log1p_total_counts', 'log1p_n_genes_by_counts'])

# %%
sc.pl.umap(all_real, color=['pct_counts_mt'])

# %%
sc.pl.umap(all_noise, color=['predicted_type', 'leiden'])

# %%
sc.pl.umap(
    all_noise,
    color=['log1p_total_counts', 'log1p_n_genes_by_counts'],
    title=['Log Transformed Total RNA Count', 'Log Transformed Number of Genes'],
)

# %%
sc.pl.umap(
    all_noise, 
    color=['pct_counts_mt'],
    title=['Percentage of Mitochondria'],
)

# %%
sc.set_figure_params(
    dpi_save=300,
    frameon=False,
    transparent=True,
)

# %%
import scanpy as sc
import matplotlib.patches as patches
import matplotlib.pyplot as plt

# %%
cmap = 'plasma'
dpi = 300
# mosaic = """AABB
#             .CC."""
mosaic = """AA
            BB
            CC"""
fig, ax_dict = plt.subplot_mosaic(mosaic, figsize=(6,12))
axes = list(ax_dict.values())

plt.rcParams.update({
    # 'text.color': font_color,
    # 'axes.labelcolor': font_color,
    # 'axes.edgecolor': font_color,
    # 'xtick.labelcolor': font_color,
    # 'ytick.labelcolor': font_color,
    'font.size': 18,          # base font size
    'axes.titlesize': 18,     # subplot titles
    'axes.labelsize': 18,     # x/y labels
    'xtick.labelsize': 18,    # x tick labels
    'ytick.labelsize': 16,    # y tick labels
    'legend.title_fontsize': 18,
    'legend.fontsize': 18,
    'figure.titlesize': 28    # main title
})

ax1 = axes[0]
sc.pl.umap(
    all_noise, 
    color='log1p_total_counts',
    ax=ax1,
    show=False,
    title='Log Transformed Total RNA Count per Cell',
    color_map=cmap,
)

ax2 = axes[1]
sc.pl.umap(
    all_noise, 
    color='log1p_n_genes_by_counts',
    ax=ax2,
    show=False,
    title='Log Transformed Number of Genes per Cell',
    color_map=cmap,
)

ax3 = axes[2]
sc.pl.umap(
    all_noise, 
    color='pct_counts_mt',
    ax=ax3,
    show=False,
    title='Percentage of Mitochondria per Cell',
    color_map=cmap,
)
fig.patch.set_alpha(0)
for ax in fig.axes:
    ax.set_facecolor("none") 
plt.tight_layout()
plt.subplots_adjust(hspace=0.2)
# plt.show()
plt.savefig("MIDAS-2025-figure-2.png", bbox_inches='tight', dpi=300)
