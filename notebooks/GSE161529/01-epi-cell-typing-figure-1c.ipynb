# %% [markdown]
# # Figure 1c
#
# This notebook recreates the visualization shown in figure 1c in the reference article.
#
# > t-SNE plot of the integrated scRNA-seq profiles of epithelial cells form 11 reduction mammoplasties. Cell colors correspond to tissue specimens.
#
# <div style="text-align: center;">
#     <img src="images/figure-1c-reference.png" alt="Figure 1c from Reference Article" width="50%">
#     <p style="font-size:90%; color:gray; text-align: center;"><em>Figure 1c from Reference Article</em></p>
# </div>

# %% [markdown]
# ## 0. Initializations

# %%
# -- imports --
from signals_in_the_noise.preprocessing.gse161529 import GSE161529

# %%
# -- dataset --
gse = GSE161529()
all_real, all_noise = gse.get_combined_epithilial_dataset(real_pca_kwargs={}, noise_pca_kwargs={}, hvg_post_stromal=True)
# Out:
# 2025-08-01 18:51:19,490 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909253_N-PM0092-Total.h5ad as AnnData object.
# 2025-08-01 18:51:19,588 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909254_N-PM0019-Total.h5ad as AnnData object.
# 2025-08-01 18:51:19,741 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909255_N-N280-Epi.h5ad as AnnData object.
# 2025-08-01 18:51:19,793 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909256_N-PM0095-Epi.h5ad as AnnData object.
# ...

# %% [markdown]
# ## 1. "Real" cells

# %%
gse.visualize_tsne(all_real, color=['specimen_id'])

# %% [markdown]
# ## 2. "Noise" cells

# %%
gse.visualize_tsne(all_noise, color=['specimen_id'])
