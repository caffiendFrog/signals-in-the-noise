# %% [markdown]
# # Figure 1d
#
# This notebook recreates the visualization shown in figure 1d in the reference article.
#
# > Same t-SNE plot as (C) [t-SNE plot of the integrated scRNA-seq profiles of epithelial cells form 11 reduction mammoplasties.] but seprated by hormonal status of the donor (8 premonopausal and 3 postmenopausal)
#
# <div style="text-align: center;">
#     <img src="images/figure-1d-reference.png" alt="Figure 1d from Reference Article" width="50%">
#     <p style="font-size:90%; color:gray; text-align: center;"><em>Figure 1d from Reference Article</em></p>
# </div>

# %% [markdown]
# ## 0. Initializations

# %%
# -- imports --
from signals_in_the_noise.preprocessing.gse161529 import GSE161529
from signals_in_the_noise.utilities.visualization import get_figure_axes

# %%
# -- dataset --
gse = GSE161529()
all_real, all_noise = gse.get_combined_epithilial_dataset()
# Out:
# 2025-07-20 17:41:36,979 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909253_N-PM0092-Total.h5ad as AnnData object.
# 2025-07-20 17:41:37,064 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909254_N-PM0019-Total.h5ad as AnnData object.
# 2025-07-20 17:41:37,186 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909255_N-N280-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,239 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909256_N-PM0095-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,366 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909257_N-PM0095-Total.h5ad as AnnData object.
# 2025-07-20 17:41:37,468 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909258_N-NF-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,532 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909259_N-NE-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,604 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909260_N-N1105-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,698 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909261_N-PM0230-Total.h5ad as AnnData object.
# 2025-07-20 17:41:37,773 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909262_N-MH0064-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,832 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909263_N-MH0064-Total.h5ad as AnnData object.
# 2025-07-20 17:41:37,879 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909264_N-N1B-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:37,938 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909265_N-PM0233-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,049 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909266_N-MH0169-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,124 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909267_N-MH0023-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:38,182 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909268_N-MH0023-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,289 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909269_N-PM0342-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:38,404 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909270_N-PM0342-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,521 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909271_N-MH288-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,578 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909272_N-MH0021-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,627 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909273_N-MH275-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:38,728 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909274_N-MH275-Total.h5ad as AnnData object.
# 2025-07-20 17:41:38,782 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909275_N-PM0372-Epi.h5ad as AnnData object.
# 2025-07-20 17:41:38,929 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909276_N-PM0372-Total.h5ad as AnnData object.
# 2025-07-20 17:41:39,024 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909277_B1-KCF0894.h5ad as AnnData object.
# 2025-07-20 17:41:39,120 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909278_B1-MH0033.h5ad as AnnData object.
# 2025-07-20 17:41:39,196 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909279_B1-MH0023.h5ad as AnnData object.
# 2025-07-20 17:41:39,269 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909280_B1-MH0090.h5ad as AnnData object.
# 2025-07-20 17:41:39,352 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909281_TN-MH0126.h5ad as AnnData object.
# 2025-07-20 17:41:39,423 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909282_TN-MH0135.h5ad as AnnData object.
# 2025-07-20 17:41:39,679 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909283_TN-SH0106.h5ad as AnnData object.
# 2025-07-20 17:41:39,734 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909284_TN-MH0114-T2.h5ad as AnnData object.
# 2025-07-20 17:41:39,798 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909285_TN-B1-MH4031.h5ad as AnnData object.
# 2025-07-20 17:41:39,953 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909286_TN-B1-MH0131.h5ad as AnnData object.
# 2025-07-20 17:41:40,090 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909287_TN-B1-Tum0554.h5ad as AnnData object.
# 2025-07-20 17:41:40,232 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909288_TN-B1-MH0177.h5ad as AnnData object.
# 2025-07-20 17:41:40,398 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909289_HER2-AH0308.h5ad as AnnData object.
# 2025-07-20 17:41:40,513 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909290_HER2-PM0337.h5ad as AnnData object.
# 2025-07-20 17:41:40,649 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909291_HER2-MH0031.h5ad as AnnData object.
# 2025-07-20 17:41:40,722 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909292_HER2-MH0069.h5ad as AnnData object.
# 2025-07-20 17:41:40,762 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909293_HER2-MH0161.h5ad as AnnData object.
# 2025-07-20 17:41:40,873 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909294_HER2-MH0176.h5ad as AnnData object.
# 2025-07-20 17:41:41,026 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909295_ER-AH0319.h5ad as AnnData object.
# 2025-07-20 17:41:41,112 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909296_ER-MH0001.h5ad as AnnData object.
# 2025-07-20 17:41:41,185 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909297_ER-MH0125.h5ad as AnnData object.
# 2025-07-20 17:41:41,269 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909298_ER-PM0360.h5ad as AnnData object.
# 2025-07-20 17:41:41,359 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909299_ER-MH0114-T3.h5ad as AnnData object.
# 2025-07-20 17:41:41,482 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909300_ER-MH0032.h5ad as AnnData object.
# 2025-07-20 17:41:41,532 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909301_ER-MH0042.h5ad as AnnData object.
# 2025-07-20 17:41:41,604 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909302_ER-MH0025.h5ad as AnnData object.
# 2025-07-20 17:41:41,740 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909303_ER-MH0151.h5ad as AnnData object.
# 2025-07-20 17:41:41,823 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909304_ER-MH0163.h5ad as AnnData object.
# 2025-07-20 17:41:41,956 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909305_ER-MH0029-7C.h5ad as AnnData object.
# 2025-07-20 17:41:42,148 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909306_ER-MH0029-9C.h5ad as AnnData object.
# 2025-07-20 17:41:42,278 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909307_ER-MH0040.h5ad as AnnData object.
# 2025-07-20 17:41:42,364 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909308_ER-MH0040-LN.h5ad as AnnData object.
# 2025-07-20 17:41:42,469 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909309_ER-MH0043-T.h5ad as AnnData object.
# 2025-07-20 17:41:42,543 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909310_ER-MH0043-LN.h5ad as AnnData object.
# 2025-07-20 17:41:42,585 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909311_ER-MH0056-T.h5ad as AnnData object.
# 2025-07-20 17:41:42,636 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909312_ER-MH0056-LN.h5ad as AnnData object.
# 2025-07-20 17:41:42,709 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909313_ER-MH0064-T.h5ad as AnnData object.
# 2025-07-20 17:41:42,774 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909314_ER-MH0064-LN.h5ad as AnnData object.
# 2025-07-20 17:41:42,824 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909315_ER-MH0167-T.h5ad as AnnData object.
# 2025-07-20 17:41:42,952 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909316_ER-MH0167-LN.h5ad as AnnData object.
# 2025-07-20 17:41:43,126 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909317_ER-MH0173-T.h5ad as AnnData object.
# 2025-07-20 17:41:43,253 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909318_ER-MH0173-LN.h5ad as AnnData object.
# 2025-07-20 17:41:43,352 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909319_mER-PM0178.h5ad as AnnData object.
# 2025-07-20 17:41:43,422 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909320_mER-MH0068-T.h5ad as AnnData object.
# 2025-07-20 17:41:43,461 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909321_mER-MH0068-LN.h5ad as AnnData object.
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...

# %%
## -- additionally filter to pre & post --
all_real_pre = all_real[all_real.obs['hormonal_status'] == 'Pre'].copy()
all_real_post = all_real[all_real.obs['hormonal_status'] == 'Post'].copy()

all_noise_pre = all_noise[all_noise.obs['hormonal_status'] == 'Pre'].copy()
all_noise_post = all_noise[all_noise.obs['hormonal_status'] == 'Post'].copy()

# %% [markdown]
# ## 1. "Real" cells

# %%
# _, axes = get_figure_axes(2, num_cols=2)
gse.visualize_tsne(all_real_pre, color=['hormonal_status'], plot_kwargs={'title': 'Pre-menopause'})
gse.visualize_tsne(all_real_post, color=['hormonal_status'], plot_kwargs={'title': 'Post-menopause'})
# Out:
# 2025-07-20 17:47:50,626 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:47:50,632 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`
# 2025-07-20 17:47:57,179 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`
# 2025-07-20 17:48:41,300 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:48:41,304 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`
# 2025-07-20 17:48:45,920 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`

# %%
gse.visualize_tsne(all_real, color=['hormonal_status'])
# Out:
# 2025-07-20 17:44:19,276 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:44:19,285 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`
# 2025-07-20 17:44:30,984 [INFO] openTSNE.tsne: Automatically determined negative gradient method `fft`
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical

# %% [markdown]
# ## 2. "Noise" cells

# %%
gse.visualize_tsne(all_noise_pre, color=['hormonal_status'], plot_kwargs={'title': 'Pre-menopause'})
gse.visualize_tsne(all_noise_post, color=['hormonal_status'], plot_kwargs={'title': 'Post-menopause'})
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)
# 2025-07-20 17:49:17,406 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:49:17,408 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# 2025-07-20 17:49:27,029 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)
# 2025-07-20 17:50:10,414 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:50:10,415 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# 2025-07-20 17:50:17,574 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical

# %%
gse.visualize_tsne(all_noise, color=['hormonal_status'])
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)
# 2025-07-20 17:45:28,018 [INFO] openTSNE.tsne: Precomputed initialization provided. Ignoring initalization-related parameters.
# 2025-07-20 17:45:28,020 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# 2025-07-20 17:45:44,015 [INFO] openTSNE.tsne: Automatically determined negative gradient method `bh`
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical
