# %% [markdown]
# # Normal breast epithelia comprise three major populations plus transient intermediates
#
# This notebook attempts to reverse engineer the analysis done to arrive at the source papers first result, normal breast tissue contains three major types of cells: basal, luminal progenitor, and mature luminal.
#
# This analysis was performed on the single-cell RNA sequencing data for 11 subjects, corresponding to the following identifiers:
# |"Sample" identifier|File identifier|
# |---|---|
# |N-1105-epi|`GSM4909260_N-N1105-Epi`|
# |N-0280-epi|`GSM4909255_N-N280-Epi`|
# |N-0230.16-epi|`GSM4909264_N-N1B-Epi`|
# |N-0408-epi|`GSM4909259_N-NE-Epi`|
# |N-1469-epi|`GSM4909258_N-NF-Epi`|
# |N-0123-epi|`GSM4909267_N-MH0023-Epi`|
# |N-0064-epi|`GSM4909313_N-MH0064-Epi`|
# |N-0093-epi|`GSM4909256_N-PM0095-Epi`|
# |N-0342-epi|`GSM4909269_N-PM0342-Epi`|
# |N-0372-epi|`GSM4909275_N-PM0372-Epi`|
# |N-0275-epi|`GSM4909273_N-MH275-Epi`|
#
# This table was arrived at through:
# * Figure 1c in the source article lists the "Sample" (quotes to emphasize in the context of the article, a sample is analogous to a human subject) identifiers used.
# * Supplementary table 1 of the source article maps identifiers to file identifiers.

# %% [markdown]
# ## 0. Initializations

# %%
# -- imports --
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc

from signals_in_the_noise.preprocessing.gse161529 import GSE161529
from signals_in_the_noise.utilities.storage import get_resources_path
from signals_in_the_noise.utilities.visualization import get_figure_axes

# %%
# -- datasets --
gse = GSE161529()
filenames = gse.EPI_CELL_TYPING_FILENAMES
# Out:
# 2025-08-01 12:51:39,863 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909253_N-PM0092-Total as AnnData object.
# 2025-08-01 12:51:41,632 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:41,724 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909254_N-PM0019-Total as AnnData object.
# 2025-08-01 12:51:44,348 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:44,462 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909255_N-N280-Epi as AnnData object.
# 2025-08-01 12:51:44,787 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:44,874 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909256_N-PM0095-Epi as AnnData object.
# 2025-08-01 12:51:48,618 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:48,758 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909257_N-PM0095-Total as AnnData object.
# 2025-08-01 12:51:51,023 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:51,128 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909258_N-NF-Epi as AnnData object.
# 2025-08-01 12:51:51,906 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:51,991 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909259_N-NE-Epi as AnnData object.
# 2025-08-01 12:51:53,015 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:53,116 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909260_N-N1105-Epi as AnnData object.
# 2025-08-01 12:51:54,886 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:54,995 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909261_N-PM0230-Total as AnnData object.
# 2025-08-01 12:51:56,337 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:56,427 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909262_N-MH0064-Epi as AnnData object.
# 2025-08-01 12:51:57,156 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:57,235 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909263_N-MH0064-Total as AnnData object.
# 2025-08-01 12:51:57,559 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:57,629 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909264_N-N1B-Epi as AnnData object.
# 2025-08-01 12:51:58,072 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:51:58,146 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909265_N-PM0233-Total as AnnData object.
# 2025-08-01 12:52:00,321 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:00,429 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909266_N-MH0169-Total as AnnData object.
# 2025-08-01 12:52:01,875 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:01,963 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909267_N-MH0023-Epi as AnnData object.
# 2025-08-01 12:52:02,669 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:02,767 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909268_N-MH0023-Total as AnnData object.
# 2025-08-01 12:52:05,283 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:05,405 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909269_N-PM0342-Epi as AnnData object.
# 2025-08-01 12:52:08,308 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:08,435 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909270_N-PM0342-Total as AnnData object.
# 2025-08-01 12:52:11,284 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:11,400 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909271_N-MH288-Total as AnnData object.
# 2025-08-01 12:52:12,017 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:12,090 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909272_N-MH0021-Total as AnnData object.
# 2025-08-01 12:52:12,395 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:12,479 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909273_N-MH275-Epi as AnnData object.
# 2025-08-01 12:52:14,754 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:14,858 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909274_N-MH275-Total as AnnData object.
# 2025-08-01 12:52:15,424 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:15,518 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909275_N-PM0372-Epi as AnnData object.
# 2025-08-01 12:52:20,452 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:20,596 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909276_N-PM0372-Total as AnnData object.
# 2025-08-01 12:52:22,460 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:22,563 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909277_B1-KCF0894 as AnnData object.
# 2025-08-01 12:52:24,785 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:24,909 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909278_B1-MH0033 as AnnData object.
# 2025-08-01 12:52:26,372 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:26,453 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909279_B1-MH0023 as AnnData object.
# 2025-08-01 12:52:27,563 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:27,653 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909280_B1-MH0090 as AnnData object.
# 2025-08-01 12:52:28,981 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:29,062 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909281_TN-MH0126 as AnnData object.
# 2025-08-01 12:52:30,123 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:30,249 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909282_TN-MH0135 as AnnData object.
# 2025-08-01 12:52:36,775 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:36,951 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909283_TN-SH0106 as AnnData object.
# 2025-08-01 12:52:37,237 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:37,297 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909284_TN-MH0114-T2 as AnnData object.
# 2025-08-01 12:52:37,746 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:37,832 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909285_TN-B1-MH4031 as AnnData object.
# 2025-08-01 12:52:40,622 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:40,742 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909286_TN-B1-MH0131 as AnnData object.
# 2025-08-01 12:52:43,189 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:43,295 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909287_TN-B1-Tum0554 as AnnData object.
# 2025-08-01 12:52:46,131 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:46,260 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909288_TN-B1-MH0177 as AnnData object.
# 2025-08-01 12:52:51,254 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:51,387 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909289_HER2-AH0308 as AnnData object.
# 2025-08-01 12:52:53,626 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:53,739 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909290_HER2-PM0337 as AnnData object.
# 2025-08-01 12:52:57,025 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:57,136 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909291_HER2-MH0031 as AnnData object.
# 2025-08-01 12:52:58,032 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:58,107 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909292_HER2-MH0069 as AnnData object.
# 2025-08-01 12:52:58,226 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:52:58,288 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909293_HER2-MH0161 as AnnData object.
# 2025-08-01 12:53:00,228 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:00,345 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909294_HER2-MH0176 as AnnData object.
# 2025-08-01 12:53:04,621 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:04,745 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909295_ER-AH0319 as AnnData object.
# 2025-08-01 12:53:05,603 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:05,690 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909296_ER-MH0001 as AnnData object.
# 2025-08-01 12:53:06,621 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:06,692 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909297_ER-MH0125 as AnnData object.
# 2025-08-01 12:53:07,752 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:07,837 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909298_ER-PM0360 as AnnData object.
# 2025-08-01 12:53:09,088 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:09,181 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909299_ER-MH0114-T3 as AnnData object.
# 2025-08-01 12:53:11,574 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:11,664 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909300_ER-MH0032 as AnnData object.
# 2025-08-01 12:53:11,950 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:12,025 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909301_ER-MH0042 as AnnData object.
# 2025-08-01 12:53:12,938 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:13,025 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909302_ER-MH0025 as AnnData object.
# 2025-08-01 12:53:15,536 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:15,643 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909303_ER-MH0151 as AnnData object.
# 2025-08-01 12:53:16,568 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:16,656 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909304_ER-MH0163 as AnnData object.
# 2025-08-01 12:53:18,598 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:18,687 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909305_ER-MH0029-7C as AnnData object.
# 2025-08-01 12:53:19,733 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:19,830 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909306_ER-MH0029-9C as AnnData object.
# 2025-08-01 12:53:22,329 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:22,440 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909307_ER-MH0040 as AnnData object.
# 2025-08-01 12:53:24,143 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:24,235 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909308_ER-MH0040-LN as AnnData object.
# 2025-08-01 12:53:26,317 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:26,428 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909309_ER-MH0043-T as AnnData object.
# 2025-08-01 12:53:27,517 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:27,595 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909310_ER-MH0043-LN as AnnData object.
# 2025-08-01 12:53:27,770 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:27,821 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909311_ER-MH0056-T as AnnData object.
# 2025-08-01 12:53:28,105 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:28,174 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909312_ER-MH0056-LN as AnnData object.
# 2025-08-01 12:53:29,302 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:29,385 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909313_ER-MH0064-T as AnnData object.
# 2025-08-01 12:53:30,077 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:30,160 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909314_ER-MH0064-LN as AnnData object.
# 2025-08-01 12:53:30,412 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:30,494 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909315_ER-MH0167-T as AnnData object.
# 2025-08-01 12:53:34,269 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:34,407 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909316_ER-MH0167-LN as AnnData object.
# 2025-08-01 12:53:35,821 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:35,917 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909317_ER-MH0173-T as AnnData object.
# 2025-08-01 12:53:38,882 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:38,991 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909318_ER-MH0173-LN as AnnData object.
# 2025-08-01 12:53:40,588 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:40,675 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909319_mER-PM0178 as AnnData object.
# 2025-08-01 12:53:41,623 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:41,690 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909320_mER-MH0068-T as AnnData object.
# 2025-08-01 12:53:41,802 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:41,862 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading GSM4909321_mER-MH0068-LN as AnnData object.
# 2025-08-01 12:53:42,499 [INFO] signals_in_the_noise.utilities.tenx_genomics: ...caching object.
# ... storing 'adata-filename' as categorical
# ... storing 'feature_types' as categorical
# 2025-08-01 12:53:42,559 [INFO] signals_in_the_noise.preprocessing.gse161529: Reading metadata from GSE161529/table_supplementary_1.xlsx...
# 2025-08-01 12:53:43,289 [INFO] signals_in_the_noise.preprocessing.gse161529: Reading phenotype from GSE161529/table_ev_4.xlsx...
# 2025-08-01 12:53:43,301 [INFO] signals_in_the_noise.preprocessing.gse161529: Reading qc from GSE161529/table_supplementary_2.xlsx...
# 2025-08-01 12:53:49,233 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909253_N-PM0092-Total.h5ad
# 2025-08-01 12:53:49,579 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909254_N-PM0019-Total.h5ad
# 2025-08-01 12:53:49,849 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909255_N-N280-Epi.h5ad
# 2025-08-01 12:53:49,905 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909256_N-PM0095-Epi.h5ad
# 2025-08-01 12:53:50,271 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909257_N-PM0095-Total.h5ad
# 2025-08-01 12:53:50,510 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909258_N-NF-Epi.h5ad
# 2025-08-01 12:53:50,611 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909259_N-NE-Epi.h5ad
# 2025-08-01 12:53:50,743 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909260_N-N1105-Epi.h5ad
# 2025-08-01 12:53:50,939 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909261_N-PM0230-Total.h5ad
# 2025-08-01 12:53:51,095 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909262_N-MH0064-Epi.h5ad
# 2025-08-01 12:53:51,200 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909263_N-MH0064-Total.h5ad
# 2025-08-01 12:53:51,255 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909264_N-N1B-Epi.h5ad
# 2025-08-01 12:53:51,324 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909265_N-PM0233-Total.h5ad
# 2025-08-01 12:53:51,553 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909266_N-MH0169-Total.h5ad
# 2025-08-01 12:53:51,783 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909267_N-MH0023-Epi.h5ad
# 2025-08-01 12:53:51,872 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909268_N-MH0023-Total.h5ad
# 2025-08-01 12:53:52,123 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909269_N-PM0342-Epi.h5ad
# 2025-08-01 12:53:52,415 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909270_N-PM0342-Total.h5ad
# 2025-08-01 12:53:52,712 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909271_N-MH288-Total.h5ad
# 2025-08-01 12:53:52,800 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909272_N-MH0021-Total.h5ad
# 2025-08-01 12:53:52,856 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909273_N-MH275-Epi.h5ad
# 2025-08-01 12:53:53,097 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909274_N-MH275-Total.h5ad
# 2025-08-01 12:53:53,175 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909275_N-PM0372-Epi.h5ad
# 2025-08-01 12:53:53,611 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909276_N-PM0372-Total.h5ad
# 2025-08-01 12:53:53,814 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909277_B1-KCF0894.h5ad
# 2025-08-01 12:53:54,041 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909278_B1-MH0033.h5ad
# 2025-08-01 12:53:54,195 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909279_B1-MH0023.h5ad
# 2025-08-01 12:53:54,332 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909280_B1-MH0090.h5ad
# 2025-08-01 12:53:54,491 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909281_TN-MH0126.h5ad
# 2025-08-01 12:53:54,610 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909282_TN-MH0135.h5ad
# 2025-08-01 12:53:55,194 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909283_TN-SH0106.h5ad
# 2025-08-01 12:53:55,247 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909284_TN-MH0114-T2.h5ad
# 2025-08-01 12:53:55,318 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909285_TN-B1-MH4031.h5ad
# 2025-08-01 12:53:55,593 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909286_TN-B1-MH0131.h5ad
# 2025-08-01 12:53:55,836 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909287_TN-B1-Tum0554.h5ad
# 2025-08-01 12:53:56,133 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909288_TN-B1-MH0177.h5ad
# 2025-08-01 12:53:56,619 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909289_HER2-AH0308.h5ad
# 2025-08-01 12:53:56,845 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909290_HER2-PM0337.h5ad
# 2025-08-01 12:53:57,167 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909291_HER2-MH0031.h5ad
# 2025-08-01 12:53:57,285 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909292_HER2-MH0069.h5ad
# 2025-08-01 12:53:57,321 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909293_HER2-MH0161.h5ad
# 2025-08-01 12:53:57,533 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909294_HER2-MH0176.h5ad
# 2025-08-01 12:53:57,955 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909295_ER-AH0319.h5ad
# 2025-08-01 12:53:58,063 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909296_ER-MH0001.h5ad
# 2025-08-01 12:53:58,180 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909297_ER-MH0125.h5ad
# 2025-08-01 12:53:58,312 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909298_ER-PM0360.h5ad
# 2025-08-01 12:53:58,477 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909299_ER-MH0114-T3.h5ad
# 2025-08-01 12:53:58,757 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909300_ER-MH0032.h5ad
# 2025-08-01 12:53:58,816 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909301_ER-MH0042.h5ad
# 2025-08-01 12:53:58,955 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909302_ER-MH0025.h5ad
# 2025-08-01 12:53:59,236 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909303_ER-MH0151.h5ad
# 2025-08-01 12:53:59,367 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909304_ER-MH0163.h5ad
# 2025-08-01 12:53:59,625 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909305_ER-MH0029-7C.h5ad
# 2025-08-01 12:53:59,778 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909306_ER-MH0029-9C.h5ad
# 2025-08-01 12:54:00,047 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909307_ER-MH0040.h5ad
# 2025-08-01 12:54:00,253 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909308_ER-MH0040-LN.h5ad
# 2025-08-01 12:54:00,500 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909309_ER-MH0043-T.h5ad
# 2025-08-01 12:54:00,653 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909310_ER-MH0043-LN.h5ad
# 2025-08-01 12:54:00,703 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909311_ER-MH0056-T.h5ad
# 2025-08-01 12:54:00,773 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909312_ER-MH0056-LN.h5ad
# 2025-08-01 12:54:00,938 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909313_ER-MH0064-T.h5ad
# 2025-08-01 12:54:01,046 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909314_ER-MH0064-LN.h5ad
# 2025-08-01 12:54:01,123 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909315_ER-MH0167-T.h5ad
# 2025-08-01 12:54:01,526 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909316_ER-MH0167-LN.h5ad
# 2025-08-01 12:54:01,711 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909317_ER-MH0173-T.h5ad
# 2025-08-01 12:54:02,035 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909318_ER-MH0173-LN.h5ad
# 2025-08-01 12:54:02,251 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909319_mER-PM0178.h5ad
# 2025-08-01 12:54:02,395 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909320_mER-MH0068-T.h5ad
# 2025-08-01 12:54:02,437 [INFO] signals_in_the_noise.preprocessing.gse161529: Applying annotations for GSM4909321_mER-MH0068-LN.h5ad

# %%
# -- utility methods --
def kde_gene_signature_score(adata, signature_name, ax):
    score_name = f'score_{signature_name}'
    x_label = f'{signature_name} score'
    title = f'Distribution of {signature_name} gene signature score'
    sns.histplot(adata.obs[score_name], kde=True, bins=50, ax=ax)
    
    ax.axvline(x=adata.obs[score_name].mean(), color='red', linestyle='--', label='Mean')
    ax.set_xlabel(x_label)
    ax.set_ylabel("Cell count")
    ax.set_title(title)
    ax.legend()

# %% [markdown]
# ## 1. Additional preprocessing
# For this finding, the authors leveraged the work of Lim *et al* (2009) [2] for the gene signatures of basal, luminal progenitor, and mature luminal signatures. Using these signatures, the authors were able to classify the sequencing data as either one of these 3 populations or other.
#
# To reproduce their analysis, I use the following supplementary files from Lim *et al* that contain the gene signature to classify the cell data:
# |Population|Filename|
# |---|---|
# |basal|`41591_2009_BFnm2000_MOESM13_ESM.xls`|
# |luminal progenitor (lp)|`41591_2009_BFnm2000_MOESM14_ESM.xls`|
# |mature luminal (ml)|`41591_2009_BFnm2000_MOESM15_ESM.xls`|

# %%
gene_signature_filenames = {
    'basal': 'epithial_cell_typing/41591_2009_BFnm2000_MOESM13_ESM.xls',
    'lp': 'epithial_cell_typing/41591_2009_BFnm2000_MOESM14_ESM.xls',
    'ml': 'epithial_cell_typing/41591_2009_BFnm2000_MOESM15_ESM.xls',
}

# %% [markdown]
# ### 1.1. Score datasets for gene signature expressions
#
# The first step in classifying the sequencing data is to score each cell for each of the 3 gene signatures. Scanpy provides [`tl.score_genes`](https://scanpy.readthedocs.io/en/stable/generated/scanpy.tl.score_genes.html) which calculates "the average expression of set of genes after substraction by the average expression of a reference set of genes."

# %%
def score_gene_signature_expression(dataset_filename, *, log_normalize=False, hvg_only=False, hvg_flavor='seurat'):
    adata = gse.get_dataset(dataset_filename)
    if log_normalize:
        print("Log normalizing dataset...")
        sc.pp.normalize_total(adata)
        sc.pp.log1p(adata)
    if hvg_only:
        print("Filtering dataset to highly variable genes...")
        sc.pp.highly_variable_genes(adata, flavor=hvg_flavor)
        adata = adata[:, adata.var['highly_variable']]
    
    for gene_signature, filename in gene_signature_filenames.items():
        # read gene signature from excel file
        signature_df = pd.read_excel(get_resources_path(gse.STUDY_ID + '/' + filename))
        genes = signature_df.loc[:, 'Symbol'].dropna().unique().tolist()        
        # only return the genes that exist in target dataset
        actual_genes = [gene for gene in genes if gene in adata.var_names]
        sc.tl.score_genes(adata, gene_list=actual_genes, score_name=f'score_{gene_signature}')
    
    return adata

def show_gene_signature_scores(adata):
    _, axes = get_figure_axes(len(gene_signature_filenames), num_cols=3, super_title="Gene Expression Distribution Scores")
    for idx, (gene_signature, filename) in enumerate(gene_signature_filenames.items()):
        kde_gene_signature_score(adata, gene_signature, axes[idx])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 1.1.1. Naive attempt to score genes
#
# First attempt to score genes, applied without any additional preprocessing to the data

# %%
filename = list(filenames.values())[0]
adata = score_gene_signature_expression(filename)
show_gene_signature_scores(adata)

# %% [markdown]
# The negative score says that the relative expression of these signatures is centerd around a mean of zero, which directly contradicts the findings in the paper. Given the right skewedness of the distributions, look at the distribution of the data to see if it needs to be log-normalized.

# %%
adata.obs['total_counts'].describe()
# Out:
# count     5201.000000
# mean      7503.861328
# std       5509.797852
# min        501.000000
# 25%       3806.000000
# 50%       6319.000000
# 75%       9639.000000
# max      59760.000000
# Name: total_counts, dtype: float64

# %% [markdown]
# These values indicate that the counts are **not** log-normalized, let's do that next.

# %% [markdown]
# #### 1.1.2. Log normalize data before scoring

# %%
adata = score_gene_signature_expression(filename, log_normalize=True)
show_gene_signature_scores(adata)
# Out:
# Log normalizing dataset...

# %% [markdown]
# #### 1.1.3. Log normalize data and filtered for highly variable genes before scoring
#
# One important note about the [format of the data](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE161529) shared by the authors. All the datasets share a single features file. In other words, the features (e.g. genes) listed in the single features file consists of all the unique features (genes) in the entire dataset (69 datasets). This results in every dataset having **33,538** features (e.g. genes, columns), where most of the expression values are zero or close to zero.

# %%
gse.get_dataset(filename).shape
# Out:
# (5201, 33538)

# %% [markdown]
# It's recommended that single-cell RNA sequencing data be filtered down to highly variable genes to more effectively use dimensionality reduction and improve signal detection.

# %%
adata = score_gene_signature_expression(filename, log_normalize=True, hvg_only=True)
show_gene_signature_scores(adata)
# Out:
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scanpy\tools\_score_genes.py:167: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[score_name] = pd.Series(

# %% [markdown]
# ### 1.2. Predict cell types
#
# Using the scoring defined in `1.1.3.`, now predict what population (type) the cell belongs to by seeing which of the 3 populations it scores the highest on. As we are expecting upregulation, if the highest value is negative, the cell will be typed as "Other".

# %%
adata = score_gene_signature_expression(filename, log_normalize=True, hvg_only=True)
# Out:
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scanpy\tools\_score_genes.py:167: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[score_name] = pd.Series(

# %% [markdown]
# #### 1.2.1. Identify the highest value

# %%
score_cols = [f"score_{k}" for k in gene_signature_filenames.keys()]
adata.obs['predicted_type'] = adata.obs[score_cols].idxmax(axis=1).str.replace('score_', '')
adata.obs['predicted_type_score'] = adata.obs[score_cols].max(axis=1)

# %% [markdown]
# #### 1.2.2. Check for negative highest values
# If there are any negative (or zero) highest values, replace the predicted type with "Other".

# %%
adata.obs['predicted_type_score'].describe()
# Out:
# count    5201.000000
# mean        0.076870
# std         0.044431
# min        -0.051358
# 25%         0.046486
# 50%         0.070808
# 75%         0.100978
# max         0.302087
# Name: predicted_type_score, dtype: float64

# %%
adata.obs.loc[adata.obs['predicted_type_score'] <= 0, 'predicted_type'] = "Other"

# %% [markdown]
# #### 1.2.3. Visualize predictions

# %%
sc.pp.neighbors(adata, use_rep='X')
sc.tl.tsne(adata)
sc.pl.tsne(adata, color=['score_basal', 'score_lp', 'score_ml', 'predicted_type'])
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scanpy\tools\_utils.py:40: UserWarning: You’re trying to run this on 3116 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(
# ... storing 'predicted_type' as categorical

# %% [markdown]
# ### 2. Test framework
#
# Before further feature engineering, check that the cell typing logic has been encapsulated.

# %%
adata.obs.columns
# Out:
# Index(['adata-filename', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes', 'total_counts_mt',
#        'log1p_total_counts_mt', 'pct_counts_mt', 'is_low_num_genes',
#        'is_high_num_genes', 'is_high_mito', 'is_high_total_count', 'is_noise',
#        'zero_genes', 'zero_mito', 'zero_count', 'score_basal', 'score_lp',
#        'score_ml', 'predicted_type', 'predicted_type_score'],
#       dtype='object')

# %%
adata = gse.annotate_epithial_cell_typing(adata)
# Out:
# Log normalizing dataset...
# WARNING: adata.X seems to be already log-transformed.
# Filtering dataset to highly variable genes...

# %%
adata.obs.columns
# Out:
# Index(['adata-filename', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes', 'total_counts_mt',
#        'log1p_total_counts_mt', 'pct_counts_mt', 'is_low_num_genes',
#        'is_high_num_genes', 'is_high_mito', 'is_high_total_count', 'is_noise',
#        'zero_genes', 'zero_mito', 'zero_count', 'score_basal', 'score_lp',
#        'score_ml', 'predicted_type', 'predicted_type_score', 'score_stromal',
#        'score_other'],
#       dtype='object')

# %%
sc.pp.neighbors(adata, use_rep='X')
sc.tl.tsne(adata)
sc.pl.tsne(adata, color=['score_basal', 'score_lp', 'score_ml', 'score_other', 'predicted_type'])
# Out:
# ... storing 'predicted_type' as categorical
