# %% [markdown]
# # Figure 1
#
# This notebook recreates a subset of the visualizations in figure 1 of the reference article for both the real and noise cells.

# %% [markdown]
# ## 0. Initializations

# %%
# -- imports --
import anndata as ad
import numpy as np
import scanpy as sc

from scipy import sparse

from signals_in_the_noise.preprocessing.gse161529 import GSE161529

# %%
def get_combined_dataset(is_noise):
    adatas = []
    is_noise_val = 1 if is_noise else 0
    for idx, filename in enumerate(gse.EPI_CELL_TYPING_FILENAMES):
        adata = gse.get_dataset(filename)
        adata.obs_names = [f"{filename}_{i}" for i in range(adata.n_obs)]
        # filter to real cells
        adata = adata[adata.obs['is_noise']==is_noise_val].copy()
        adata = gse.annotate_epithial_cell_typing(adata)
        # remove stromal cells - "...removed the stromal subset..."
        mask = ~adata.obs['predicted_type'].str.lower().str.contains('stromal')
        adata = adata[mask].copy()
        # additional features for visualizations
        adata.obs['specimen_id'] = str(idx)
        adata.obs['hormonal_status'] = adata.uns['menopause_status']
        # just in case
        if sparse.issparse(adata.X):
            adata.X = adata.X.toarray()
        adatas.append(adata)
    return ad.concat(adatas, join='inner')

def figure_1_tsne(adata_all, color, use_raw=False):
    sc.pp.scale(adata_all)
    sc.pp.pca(adata_all, random_state=random_kwargs['random_state'])
    sc.pp.neighbors(adata_all, **random_kwargs)
    # use of leiden and resolution specified in caption for Figure 1E
    sc.tl.leiden(adata_all, resolution=0.015)
    sc.tl.tsne(adata_all, **random_kwargs)
    sc.pl.tsne(adata_all, color=color, use_raw=use_raw)

# %%
# -- dataset --
gse = GSE161529()

# -- constants --
random_kwargs = {'use_rep': 'X_pca', 'random_state': 43}
# Out:
# 2025-07-13 15:03:16,428 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909253_N-PM0092-Total.h5ad as AnnData object.
# 2025-07-13 15:03:16,519 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909254_N-PM0019-Total.h5ad as AnnData object.
# 2025-07-13 15:03:16,645 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909255_N-N280-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:16,701 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909256_N-PM0095-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:16,838 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909257_N-PM0095-Total.h5ad as AnnData object.
# 2025-07-13 15:03:16,951 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909258_N-NF-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,017 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909259_N-NE-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,093 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909260_N-N1105-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,198 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909261_N-PM0230-Total.h5ad as AnnData object.
# 2025-07-13 15:03:17,287 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909262_N-MH0064-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,353 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909263_N-MH0064-Total.h5ad as AnnData object.
# 2025-07-13 15:03:17,406 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909264_N-N1B-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,459 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909265_N-PM0233-Total.h5ad as AnnData object.
# 2025-07-13 15:03:17,570 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909266_N-MH0169-Total.h5ad as AnnData object.
# 2025-07-13 15:03:17,653 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909267_N-MH0023-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,718 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909268_N-MH0023-Total.h5ad as AnnData object.
# 2025-07-13 15:03:17,829 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909269_N-PM0342-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:17,956 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909270_N-PM0342-Total.h5ad as AnnData object.
# 2025-07-13 15:03:18,084 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909271_N-MH288-Total.h5ad as AnnData object.
# 2025-07-13 15:03:18,147 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909272_N-MH0021-Total.h5ad as AnnData object.
# 2025-07-13 15:03:18,193 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909273_N-MH275-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:18,302 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909274_N-MH275-Total.h5ad as AnnData object.
# 2025-07-13 15:03:18,359 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909275_N-PM0372-Epi.h5ad as AnnData object.
# 2025-07-13 15:03:18,517 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909276_N-PM0372-Total.h5ad as AnnData object.
# 2025-07-13 15:03:18,616 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909277_B1-KCF0894.h5ad as AnnData object.
# 2025-07-13 15:03:18,718 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909278_B1-MH0033.h5ad as AnnData object.
# 2025-07-13 15:03:18,800 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909279_B1-MH0023.h5ad as AnnData object.
# 2025-07-13 15:03:18,875 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909280_B1-MH0090.h5ad as AnnData object.
# 2025-07-13 15:03:18,955 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909281_TN-MH0126.h5ad as AnnData object.
# 2025-07-13 15:03:19,025 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909282_TN-MH0135.h5ad as AnnData object.
# 2025-07-13 15:03:19,240 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909283_TN-SH0106.h5ad as AnnData object.
# 2025-07-13 15:03:19,287 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909284_TN-MH0114-T2.h5ad as AnnData object.
# 2025-07-13 15:03:19,340 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909285_TN-B1-MH4031.h5ad as AnnData object.
# 2025-07-13 15:03:19,463 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909286_TN-B1-MH0131.h5ad as AnnData object.
# 2025-07-13 15:03:19,570 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909287_TN-B1-Tum0554.h5ad as AnnData object.
# 2025-07-13 15:03:19,694 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909288_TN-B1-MH0177.h5ad as AnnData object.
# 2025-07-13 15:03:19,850 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909289_HER2-AH0308.h5ad as AnnData object.
# 2025-07-13 15:03:19,977 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909290_HER2-PM0337.h5ad as AnnData object.
# 2025-07-13 15:03:20,107 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909291_HER2-MH0031.h5ad as AnnData object.
# 2025-07-13 15:03:20,177 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909292_HER2-MH0069.h5ad as AnnData object.
# 2025-07-13 15:03:20,220 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909293_HER2-MH0161.h5ad as AnnData object.
# 2025-07-13 15:03:20,333 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909294_HER2-MH0176.h5ad as AnnData object.
# 2025-07-13 15:03:20,480 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909295_ER-AH0319.h5ad as AnnData object.
# 2025-07-13 15:03:20,547 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909296_ER-MH0001.h5ad as AnnData object.
# 2025-07-13 15:03:20,619 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909297_ER-MH0125.h5ad as AnnData object.
# 2025-07-13 15:03:20,697 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909298_ER-PM0360.h5ad as AnnData object.
# 2025-07-13 15:03:20,779 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909299_ER-MH0114-T3.h5ad as AnnData object.
# 2025-07-13 15:03:20,894 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909300_ER-MH0032.h5ad as AnnData object.
# 2025-07-13 15:03:20,944 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909301_ER-MH0042.h5ad as AnnData object.
# 2025-07-13 15:03:21,016 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909302_ER-MH0025.h5ad as AnnData object.
# 2025-07-13 15:03:21,127 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909303_ER-MH0151.h5ad as AnnData object.
# 2025-07-13 15:03:21,212 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909304_ER-MH0163.h5ad as AnnData object.
# 2025-07-13 15:03:21,318 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909305_ER-MH0029-7C.h5ad as AnnData object.
# 2025-07-13 15:03:21,397 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909306_ER-MH0029-9C.h5ad as AnnData object.
# 2025-07-13 15:03:21,509 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909307_ER-MH0040.h5ad as AnnData object.
# 2025-07-13 15:03:21,593 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909308_ER-MH0040-LN.h5ad as AnnData object.
# 2025-07-13 15:03:21,700 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909309_ER-MH0043-T.h5ad as AnnData object.
# 2025-07-13 15:03:21,779 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909310_ER-MH0043-LN.h5ad as AnnData object.
# 2025-07-13 15:03:21,824 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909311_ER-MH0056-T.h5ad as AnnData object.
# 2025-07-13 15:03:21,880 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909312_ER-MH0056-LN.h5ad as AnnData object.
# 2025-07-13 15:03:21,961 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909313_ER-MH0064-T.h5ad as AnnData object.
# 2025-07-13 15:03:22,027 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909314_ER-MH0064-LN.h5ad as AnnData object.
# 2025-07-13 15:03:22,079 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909315_ER-MH0167-T.h5ad as AnnData object.
# 2025-07-13 15:03:22,212 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909316_ER-MH0167-LN.h5ad as AnnData object.
# 2025-07-13 15:03:22,296 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909317_ER-MH0173-T.h5ad as AnnData object.
# 2025-07-13 15:03:22,423 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909318_ER-MH0173-LN.h5ad as AnnData object.
# 2025-07-13 15:03:22,518 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909319_mER-PM0178.h5ad as AnnData object.
# 2025-07-13 15:03:22,597 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909320_mER-MH0068-T.h5ad as AnnData object.
# 2025-07-13 15:03:22,641 [INFO] signals_in_the_noise.utilities.tenx_genomics: Reading C:\Users\silly\GitHub\signals-in-the-noise\data\GSE161529_adata_cache\GSM4909321_mER-MH0068-LN.h5ad as AnnData object.

# %%
# -- separate data on noise --
adata_all_real = get_combined_dataset(is_noise=False)
adata_all_noise = get_combined_dataset(is_noise=True)
# Out:
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...
# Log normalizing dataset...
# Filtering dataset to highly variable genes...

# %%
thing = 1
match thing:
    case 1:
        print('hi')
    case _:
        print('no')
# Out:
# hi

# %% [markdown]
# ## 1. Visualization B (density plot of CD59f and EpCAm expression)

# %% [markdown]
# ### 1.1. Real Cells

# %% [markdown]
# ### 1.2. Noise cells

# %% [markdown]
# ## 2. Visualization C (t-SNE colored by tissue specimens)

# %% [markdown]
# ### 2.1. Real cells

# %%
figure_1_tsne(adata_all_real, color=['specimen_id'])
# Out:
# C:\Users\silly\AppData\Local\Temp\ipykernel_47680\4213602779.py:27: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata_all, resolution=0.015)
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical

# %% [markdown]
# ### 2.2. Noise cells

# %%
figure_1_tsne(adata_all_noise, color=['specimen_id'])
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)
# ... storing 'predicted_type' as categorical
# ... storing 'specimen_id' as categorical
# ... storing 'hormonal_status' as categorical

# %% [markdown]
# ## 3. Visualization D (t-SNE colored by hormonal status)

# %% [markdown]
# ### 3.1. Real cells

# %%
figure_1_tsne(adata_all_real, color=['hormonal_status'])

# %% [markdown]
# ### 3.2. Noise cells

# %%
figure_1_tsne(adata_all_noise, color=['hormonal_status'])
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ## 4. Visualization E (t-SNE colored by cell clusters)

# %% [markdown]
# ### 4.1. Real cells

# %%
figure_1_tsne(adata_all_real, color=['predicted_type'])

# %% [markdown]
# ### 4.2. Noise cells

# %%
figure_1_tsne(adata_all_noise, color=['predicted_type'])
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ## 5. Visualization H (expression of marker genes)

# %%
adata = next(iter(gse.objects.values()))
genes = adata.var_names.tolist()
targets = [
    'EPCAM',
    'KRT5',
    'ACTA2',
    'MYLK',
    'SNAI2',
    'NOTCH4',
    'DKK3',
    'ITGA6',  # gene symbol for CD49f
    'ESR1',
    'PGR',
    'FOXA1',
    'TNFRSF11A',
    'KIT',
    'SOX10',
]
valid = [t for t in targets if t in genes]
missing = [t for t in targets if t not in genes]
len(targets) == len(valid), len(valid), len(missing)
# Out:
# (True, 14, 0)

# %%
# adata.obs["EPCAM_EXPR"] = adata[:, "EPCAM"].X.toarray().flatten()
# epcam_expr = adata.obs["EPCAM_EXPR"]
# import seaborn as sns
# sns.histplot(epcam_expr)
# print("Min:", np.min(epcam_expr))
# print("Median:", np.median(epcam_expr))
# print("Max:", np.max(epcam_expr))
# print("90th percentile:", np.percentile(epcam_expr, 90))

# %%
epcam_expr.describe()

# %% [markdown]
# ### 5.1. Real Cells

# %% [markdown]
# ### 5.2. Noise Cells

# %%
figure_1_tsne(adata_all_noise, color=[targets[0]], use_raw=True)
# Out:
# C:\Users\silly\GitHub\signals-in-the-noise\.venv\Lib\site-packages\scipy\sparse\_index.py:210: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray(i, j, x)
